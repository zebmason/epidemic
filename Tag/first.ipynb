# %%
import sys
sys.path.append( "..")

import plot

# %%
t, s, i, r, ssd, isd, rsd = plot.load('first.csv')

# %%
print(s)
# Out:
# [30.0, 28.0, 24.0, 18.0, 11.0, 7.0, 4.0, 4.0]

# %%
print(i)
# Out:
# [1.0, 2.0, 4.0, 6.0, 7.0, 4.0, 3.0, 0.0]

# %%
print(r)
# Out:
# [0.0, 1.0, 3.0, 7.0, 13.0, 20.0, 24.0, 27.0]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Exponential growth
exp_i = [1, 2, 4, 8, 16]
exp_r = [0, 1, 3, 7, 15, 31]

# %%
plt.plot(t, i, 'b', label="Game")
plt.plot(t[:5], exp_i, 'r', label="Exponential growth")
plt.xlabel("Generation")
plt.ylabel("Tagged")
plt.xlim(0, len(t)-1)
plt.ylim(0, 16)
plt.legend()

# %%
plt.plot(t, r, 'b', label="Game")
plt.plot(t[:6], exp_r, 'r', label="Exponential growth")
plt.xlabel("Generation")
plt.ylabel("No longer tagged")
plt.xlim(0, len(t)-1)
plt.ylim(0, 31)
plt.legend()
